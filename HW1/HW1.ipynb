# %%
import cv2
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
os.chdir('/content/drive/MyDrive/CV')
os.listdir()
# Out:
# ['lena_gray.gif',
#  'lena_color.gif',
#  'lena30.jpg',
#  'leangray.jpg',
#  'lena_color.jpg',
#  'lena_resize.jpg',
#  'myphoto.jpg']

# %%
image1=cv2.imread('myphoto.jpg')
type(image1)
# Out:
# numpy.ndarray

# %%
print(f"height:{image1.shape[0]} pixels")
print(f"width:{image1.shape[1]} pixels")
print(f"channel:{image1.shape[2]} pixels")
# Out:
# height:673 pixels
# width:641 pixels
# channel:3 pixels

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=641x673>

# %%
from PIL import Image


image2=Image.open('myphoto.jpg')
type(image2)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
display(image2)
print(image2.size)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=641x673>
# (641, 673)

# %%
width=256
ratio=float(width)/image2.size[0]
height=int(image2.size[1]*ratio)
nim=image2.resize((width,height), Image.BILINEAR)
print(nim.size)
display(nim)
# Out:
# (256, 268)
# <PIL.Image.Image image mode=RGB size=256x268>

# %%
width=256
height=256
nim=image2.resize((width,height), Image.BILINEAR)
print(nim.size)
display(nim)
# Out:
# (256, 256)
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
nim.save('HW1.jpg')
print(nim.mode,nim.format)
display(nim)
# Out:
# RGB None
# <PIL.Image.Image image mode=RGB size=256x256>
